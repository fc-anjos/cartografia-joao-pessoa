# %%
import geopandas as gpd
import fiona 
import pandas as pd
from bs4 import BeautifulSoup
import shapely
import re

# %%
base_os = gpd.read_file('./data/BASES/OS/João_Pessoa_planet_osm_polygon_polygons.shp')

# %%
base_os.plot()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-fb686ffba00b> in <module>
#       1 base_os.plot()
# ----> 2 plt.show()
#
# NameError: name 'plt' is not defined

# %%
setores = gpd.read_file('./data/shp/jp_shp.shp')
setores = setores[['CD_GEOCODI', 'NM_BAIRRO', 'geometry']]

# %%
bairros = setores.dissolve(by='NM_BAIRRO', aggfunc='sum')

# %%
bairros_interesse = ['Torre', 'Tambauzinho', 'Expedicionários', 'Miramar', 'Castelo Branco', 'Pedro Gondim', 'Estados']
setores_recorte = setores.loc[setores['NM_BAIRRO'].isin(bairros_interesse)]

# %%
limite_recorte = extract_border(setores_recorte)
limite_municipio = extract_border(bairros)

# %%
setores_recorte.to_file("./data/BASES/setores/setores.shp")
bairros.to_file("./data/BASES/bairros/bairros.shp")
limite_recorte.to_file("./data/BASES/limite_recorte/limite_recorte.shp")
limite_municipio.to_file("./data/BASES/limite_municipio/limite_municipio.shp")
quadras_df.to_file("./data/BASES/quadras/quadras.shp")
