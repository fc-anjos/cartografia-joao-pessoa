# %%
import geopandas as gpd

# %%
shp_path = ('./data/shp/25SEE250GC_SIR.shp')
shp = gpd.read_file(shp_path)
jp_shp = shp[shp['NM_MUNICIP'].str.contains("JOÃO PESSOA")]
jp_shp.to_file("./data/shp/jp_shp.shp")
