# %%
import geopandas as gpd
import time
import pandas as pd
import subprocess

# %%
def to_kml(df, output):
    command = "ogr2ogr -f KML {0}.kml {0}.json ".format(output)
    with open('{0}.json'.format(output), 'w') as f:
        f.write(df.to_crs(epsg=4326).to_json())
        
    subprocess.call(command,shell=True)
    
def export(df, output):
    kml_output = './OUTPUT/KML/' + output 
    csv_output = './OUTPUT/CSV/' + output + '.csv'
    shp_output = './OUTPUT/SHP/' + output
    
    to_kml(df, kml_output)
    df.to_file(shp_output)
    without_geometry = df.loc[:, df.columns != 'geometry']
    without_geometry.to_csv(csv_output)

# %%
shoppings = {
    'Manaíra Shopping':
    'Av. Gov. Flávio Ribeiro Coutinho, 805',

    'Mag Shopping':
    'Av. Gov. Flávio Ribeiro Coutinho, 115',

    'Mangabeira Shopping':
    'Av. Hílton Souto Maior, S/N',

    'Shopping Centro Terceirão':
    'R. Duque de Caxias, 200',

    'Bessa Shopping':
    'Bessa Shopping - R. Francisco Leocádio Ribeiro Coutinho, 55 - Sala 106',

    'Shopping Cidade':
    'Praça João Pessoa, 105',

    'Shopping Sul':
    'Avenida, R. Bancário Sérgio Guerra, 900',

    'Shopping Tambiá':
    'R. Dep. Odon Bezerra, 184',

    'Liv Mall':
    'Av. Gov. Flávio Ribeiro Coutinho, 500',

    'SHOPPING PIRAMIDE':
    'Av. Antônio Lira, 314',

    'Shopping Varadouro':
    'Shopping, R. Maciel Pinheiro, 548',

    'Edifcio Tambaú Center':
    'Av. Sen. Ruy Carneiro, 215',

    'Moriah Shopping':
    'Av. Pres. Epitácio Pessoa, 2580',

    'Praia Shopping':
    'Av. Gov. Flávio Ribeiro Coutinho, 300',

    'Praça de Alimentação - Mangabeira Shopping.':
    'Av. Hílton Souto Maior, 3009',

    'Shopping Centro Quatro 400':
    'Av. Beaurepaire Rohan, 66-100',

    'Centro de Comercio e Serviços do Varadouro':
    'R. Maciel Pinheiro',

    'C.C.P':
    'R. Des. Souto Maior, 310',

    'Galeria Extra João Pessoa Tambaú':
    'Av. Pres. Epitácio Pessoa, 1277',

    'Mira Center':
    'R. Ns. dos Navegantes, 83' }

df = pd.DataFrame.from_dict(shoppings, orient='index', columns=['endereco'])

# %%
geo = gpd.tools.geocode(df['endereco'], provider='GoogleV3', api_key='AIzaSyAKcpf1xqj5_T20NxGb1RmKHf43VDs4xCw', timeout=1)

# %%
geo
# Out:
#                                                              geometry  address
# Manaíra Shopping                             GEOMETRYCOLLECTION EMPTY      NaN
# Mag Shopping                                 GEOMETRYCOLLECTION EMPTY      NaN
# Mangabeira Shopping                          GEOMETRYCOLLECTION EMPTY      NaN
# Shopping Centro Terceirão                    GEOMETRYCOLLECTION EMPTY      NaN
# Bessa Shopping                               GEOMETRYCOLLECTION EMPTY      NaN
# Shopping Cidade                              GEOMETRYCOLLECTION EMPTY      NaN
# Shopping Sul                                 GEOMETRYCOLLECTION EMPTY      NaN
# Shopping Tambiá                              GEOMETRYCOLLECTION EMPTY      NaN
# Liv Mall                                     GEOMETRYCOLLECTION EMPTY      NaN
# SHOPPING PIRAMIDE                            GEOMETRYCOLLECTION EMPTY      NaN
# Shopping Varadouro                           GEOMETRYCOLLECTION EMPTY      NaN
# ...

# %%
#shoppings = shoppings.to_crs(epsg=3857)

#shoppings.to_file("./data/BASES/SHOPPINGS/shoppings.shp")

# %%
shoppings = gpd.read_file('./data/BASES/SHOPPINGS/shoppings.shp')
shoppings.set_index('index')

export(shoppings, 'shoppings')
