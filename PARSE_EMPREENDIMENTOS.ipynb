# %%
import fiona 
import geopandas as gpd
import pandas as pd
import re
from bs4 import BeautifulSoup
import os
import shapely

from lib.parse import *

# %%
# Enable fiona driver
gpd.io.file.fiona.drvsupport.supported_drivers['KML'] = 'rw'

# %%
empreendimentos_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-5aaad2ace36d> in <module>
# ----> 1 empreendimentos_df
#
# NameError: name 'empreendimentos_df' is not defined

# %%
empreendimentos_df = empreendimentos_df[['geometry', 'Name']]

# %%
empreendimentos_df = empreendimentos_df.to_crs(epsg=3857)

# %%
empreendimentos_df.to_file("./data/BASES/empreendimento/empreendimento.shp")
